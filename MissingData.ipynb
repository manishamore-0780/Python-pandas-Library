# %%
import numpy as np
import pandas as pd

# %%
Finding Missing Data

# %%
data = {
    'A': [1,np.nan,'zeal',2,3,np.nan],
    'B': [2,np.nan,'CO',4,6,np.nan],
    'C': [1,np.nan,'SIT',2,np.nan,8],
    'D': [1,np.nan,'ZCOER',np.nan,3,9]

}
df= pd.DataFrame(data)

# %%
df
# Out:
#       A    B    C      D
# 0     1    2    1      1
# 1   NaN  NaN  NaN    NaN
# 2  zeal   CO  SIT  ZCOER
# 3     2    4    2    NaN
# 4     3    6  NaN      3
# 5   NaN  NaN    8      9

# %%
df.isna()
# Out:
#        A      B      C      D
# 0  False  False  False  False
# 1   True   True   True   True
# 2  False  False  False  False
# 3  False  False  False   True
# 4  False  False   True  False
# 5   True   True  False  False

# %%
df.isna().sum()
# Out:
# A    2
# B    2
# C    2
# D    2
# dtype: int64

# %%
df.isna().any()
# Out:
# A    True
# B    True
# C    True
# D    True
# dtype: bool

# %%
Removing Missimg Data #Row wise selection

# %%
df
# Out:
#       A    B    C      D
# 0     1    2    1      1
# 1   NaN  NaN  NaN    NaN
# 2  zeal   CO  SIT  ZCOER
# 3     2    4    2    NaN
# 4     3    6  NaN      3
# 5   NaN  NaN    8      9

# %%
df.dropna()
# Out:
#       A   B    C      D
# 0     1   2    1      1
# 2  zeal  CO  SIT  ZCOER

# %%
df.dropna(thresh=0)
# Out:
#       A    B    C      D
# 0     1    2    1      1
# 1   NaN  NaN  NaN    NaN
# 2  zeal   CO  SIT  ZCOER
# 3     2    4    2    NaN
# 4     3    6  NaN      3
# 5   NaN  NaN    8      9

# %%
df
# Out:
#       A    B    C      D
# 0     1    2    1      1
# 1   NaN  NaN  NaN    NaN
# 2  zeal   CO  SIT  ZCOER
# 3     2    4    2    NaN
# 4     3    6  NaN      3
# 5   NaN  NaN    8      9

# %%
df.dropna(thresh=5)
# Out:
# Empty DataFrame
# Columns: [A, B, C, D]
# Index: []

# %%
df.dropna(thresh=4)
# Out:
#       A   B    C      D
# 0     1   2    1      1
# 2  zeal  CO  SIT  ZCOER

# %%
df.dropna(thresh=2)
# Out:
#       A    B    C      D
# 0     1    2    1      1
# 2  zeal   CO  SIT  ZCOER
# 3     2    4    2    NaN
# 4     3    6  NaN      3
# 5   NaN  NaN    8      9

# %%
Filling The Missing Data #columnwise selection

# %%
df
# Out:
#       A    B    C      D
# 0     1    2    1      1
# 1   NaN  NaN  NaN    NaN
# 2  zeal   CO  SIT  ZCOER
# 3     2    4    2    NaN
# 4     3    6  NaN      3
# 5   NaN  NaN    8      9

# %%
df.fillna('yes')
# Out:
#       A    B    C      D
# 0     1    2    1      1
# 1   yes  yes  yes    yes
# 2  zeal   CO  SIT  ZCOER
# 3     2    4    2    yes
# 4     3    6  yes      3
# 5   yes  yes    8      9

# %%
df
# Out:
#       A    B    C      D
# 0     1    2    1      1
# 1   NaN  NaN  NaN    NaN
# 2  zeal   CO  SIT  ZCOER
# 3     2    4    2    NaN
# 4     3    6  NaN      3
# 5   NaN  NaN    8      9

# %%
values={ 'A':700,'B':866,'C':500,'D':900}
df.fillna(value=values)
# Out:
#       A    B    C      D
# 0     1    2    1      1
# 1   700  866  500    900
# 2  zeal   CO  SIT  ZCOER
# 3     2    4    2    900
# 4     3    6  500      3
# 5   700  866    8      9

# %%
df
# Out:
#       A    B    C      D
# 0     1    2    1      1
# 1   NaN  NaN  NaN    NaN
# 2  zeal   CO  SIT  ZCOER
# 3     2    4    2    NaN
# 4     3    6  NaN      3
# 5   NaN  NaN    8      9

# %%
df.fillna(df.mean(numeric_only=True), inplace=True)
df
# Out:
#       A    B    C      D
# 0     1    2    1      1
# 1   NaN  NaN  NaN    NaN
# 2  zeal   CO  SIT  ZCOER
# 3     2    4    2    NaN
# 4     3    6  NaN      3
# 5   NaN  NaN    8      9

# %%
df
# Out:
#       A    B    C      D
# 0     1    2    1      1
# 1   NaN  NaN  NaN    NaN
# 2  zeal   CO  SIT  ZCOER
# 3     2    4    2    NaN
# 4     3    6  NaN      3
# 5   NaN  NaN    8      9

# %%
new_df = df.fillna(df.mean(numeric_only=True))

print(new_df)
# Out:
#       A    B    C      D
# 0     1    2    1      1
# 1   NaN  NaN  NaN    NaN
# 2  zeal   CO  SIT  ZCOER
# 3     2    4    2    NaN
# 4     3    6  NaN      3
# 5   NaN  NaN    8      9
